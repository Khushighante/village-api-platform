# %% [markdown]
# # Notebook 4 — Sector Clustering Engine (Unsupervised ML)
# ### Objective: Extract feature sets per company and train K-Means/DBSCAN profiles.

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
print('🚀 Unsupervised Machine Learning Environment Ready.')
